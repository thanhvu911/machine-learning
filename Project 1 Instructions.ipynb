# %% [markdown]
# # Project 1: Build Your Own Dataset

# %% [markdown]
# ## Learning Objectives
#
# **By the end of this project, you will be able to:**
#
# 1.  Articulate the motivation, composition, and collection process of a dataset to ensure transparency and ethical awareness.
# 2.  Demonstrate proficiency in loading, inspecting, and statistically summarizing raw datasets using the Pandas library.
# 3.  Identify and rectify common data quality issues, including handling missing values, removing duplicates, and managing outliers.
# 4.  Create univariate and bivariate visualizations to interpret feature distributions and identify correlations between variables.
# 5.  Transform raw data into machine-learning-ready formats by implementing scaling for numerical features and encoding for categorical variables.
# 6.  Critically analyze the data curation process and evaluate how techniques scale with larger datasets.

# %% [markdown]
# ## Collaboration
# If you used any outside resources or collaborated with any classmates on this project, please list them below:
#
# [collaboration notes here]

# %% [markdown]
# https://stackoverflow.com/questions/40758562/can-anyone-explain-me-standardscaler, https://scikit-learn.org/stable/modules/preprocessing.html,

# %% [markdown]
# # Part 1 - Collect your data

# %% [markdown]
# In this part, you will collect a dataset based on a topic of your choice. Some examples that I might choose for myself are: rock albums released between 1970 and 1990, science fiction books that include robots, my scores on the Chrome dinosaur game (I have actually done
# this), or tea imports to the US. You are encouraged to be creative!
#
# The requirements of your
# dataset are the following:
# - You must create the dataset yourself. Finding one that someone else already made is not appropriate. If you would like to combine several pre-existing datasets, come ask me first. You may obtain the values by measuring them yourself (ex: collecting leaves on campus and taking measurements with a ruler) or searching/compiling data from the internet.
# - Your dataset must have at least 50 data points (rows), not including the header row.
# - Your dataset must have at least 5 features (columns). You should have at least one numeric feature and at least one categorical feature. You may have a column for a unique ID for each data point if you would like, but it is not required nor does it count as a feature.
# - Your dataset must be saved as a `.csv` file with descriptive column names in the first row. I
# recommend using Python variable naming conventions.
#
# **Upload your raw (before cleaning) `.csv` file to Canvas along with this completed notebook.**

# %% [markdown]
# # Part 2 - Document your data

# %% [markdown]
# ## Dataset Description
#
# **Briefly describe what your dataset is about.**

# %% [markdown]
# This dataset contains information about the top 50 most played games on Steam as of January 2026, including details such as release year, developer, primary genre, price, current players, peak players today, user rating, and number of reviews.

# %% [markdown]
# **Describe the features of your dataset.** What does each column represent? What are the expected values each feature can take?

# %% [markdown]
# game_name: The name of the game (string).
#
# release_year: The year the game was released (integer, e.g., 2012-2025).
#
# developer: The primary developer of the game (string, categorical).
#
# primary_genre: The main genre of the game (string, categorical, e.g., Action, Strategy).
#
# price_usd: The current price in USD (float, 0 for free, positive numbers for paid).
#
# current_players: Number of current concurrent players (integer).
#
# peak_today: Peak concurrent players today (integer).
#
# user_rating: User review rating as percentage positive (float, 0-100).
#
# num_reviews: Number of user reviews (integer).

# %% [markdown]
# *Answer the following questions based on sections 3.1 - 3.5 of the [Datasheets for Datasets](https://arxiv.org/pdf/1803.09010) (DfD) paper, even if some of them appear obvious.* Your answers should make sense to someone who has never seen your dataset before. You may want to answer some of these questions after you have cleaned and explored your dataset in the next part of the project. ***The goal is to get you thinking about these questions as a data scientist. You are allowed to use N/A on questions that do not apply to your dataset.***

# %% [markdown]
# ## DfD 3.1 - Motivation
# * **For what purpose was the dataset created?**
#     * This dataset was created to analyze the most popular Steam games by player count in 2026, to understand trends in genres, pricing, and user reception.
# * **Who created the dataset (e.g., which team, research group) and on behalf of which entity (e.g., company, institution, corporation)?**
#     * Created by Thanh, as part of a personal project for learning machine learning.
# * **Any other comments?**
#     * N/A

# %% [markdown]
# ## DfD 3.2 - Composition
# * **What do the instances that comprise the dataset represent (e.g., documents, photos, people, countries)?**
#     * Each instance represents a video game on the Steam platform.
# * **How many instances are there in total (of each type, if appropriate)?**
#     * 50 instances.
# * **Does the dataset contain all possible instances or is it a sample (not necessarily random) of instances from a larger set?**
#     * It is the top 50 most played games on Steam platform in Jan 2026.
# * **Is there a label or target associated with each instance? If so, please describe.**
#     * Predicting the trend of games on the steam platform, the price trend
# * **Is any information missing from individual instances? If so, please describe. (This does not include intentionally removed information, but might include, e.g., redacted text.)**
#     * No missing info; all fields complete.
# * **Are relationships between individual instances made explicit (e.g., users’ movie ratings, social network links)? If so, please describe.**
#     * No.
# * **Are there recommended data splits (e.g., training, development/validation,testing)? If so, please describe.**
#     * No.
# * **Are there any errors, sources of noise, or redundancies in the dataset? If so, please describe.**
#     * Possible noise from real-time player counts fluctuating; no redundancies or known errors.
# * **Does the dataset contain data that might be considered confidential? If so, please describe.**
#     * No. It's self-contained CSV, sourced from public Steam pages
# * **Does the dataset contain data that, if viewed directly, might be offensive, insulting, threatening, or might otherwise cause anxiety? If so, please describe why.**
#     * No.
# * **Does the dataset contain data that might be considered sensitive in any way (e.g., data that reveals race or ethnic origins, sexual orientations, religious beliefs, political opinions or union memberships, or locations; financial or health data; biometric or genetic data; forms of government identification, such as social security numbers; criminal history)? If so, please describe.**
#     * No.
# * **Any other comments?**
#     * N/A

# %% [markdown]
# ## DfD 3.3 - Collection Process
# * **How was the data associated with each instance acquired?**
#     * Data was compiled from Steam store pages and charts using web browsing and known information.
# * **What mechanisms or procedures were used to collect the data (e.g., hardware sensor, manual human curation, software program, software API)?**
#     * Manual human curation
# * **Over what timeframe was the data collected?**
#     * January 2026.
# * **Did the individuals in question consent to the collection and use of their data?**
#     * No, public data
# * **If consent was obtained, were the consenting individuals provided with a mechanism to revoke their consent in the future or for certain uses?**
#     * N/A
# * **Any other comments?**
#     * N/A

# %% [markdown]
# ## DfD - 3.4 Preprocessing/Cleaning/Labeling
# * **Was any preprocessing/cleaning/labeling of the data done (e.g., discretization or bucketing, tokenization, part-of-speech tagging, SIFT feature extraction, removal of instances, processing of missing values)?**
#     * No
# * **Was the "raw" data saved in addition to the preprocessed/cleaned/labeled data (e.g., to support unanticipated future uses)?**
#     * No

# %% [markdown]
# ## DfD 3.5 - Uses
# * **Has the dataset been used for any tasks already?**
#     * Used for EDA, visualization, and preprocessing.
# * **What (other) tasks could the dataset be used for?**
#     * Predicting user ratings from player counts, genre clustering, price analysis.
# * **Are there tasks for which the dataset should not be used?**
#     * Not for inferring overall game quality or market diversity, as it's top-only.
# * **Is there anything about the composition of the dataset or the way it was collected and preprocessed/cleaned/labeled that might impact future uses? For example, is there anything that a dataset consumer might need to know to avoid uses that could result in unfair treatment of individuals or groups (e.g., stereotyping, quality of service issues) or other risks or harms (e.g., legal risks, "nancial harms)? If so, please provide a description. Is there anything a dataset consumer could do to mitigate these risks or harms?**
#     * The dataset is biased towards popular games, so not representative of all Steam games. Mitigate by combining with other datasets.
# * **Any other comments?**
#     * N/A

# %% [markdown]
# # Part 3 - Clean and Explore your data

# %% [markdown]
# ## Setup
#
# Import the necessary libraries you need.

# %%
import pandas as pd
import matplotlib.pyplot as plt


from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %% [markdown]
# Load your `.csv` file into a pandas DataFrame, and output the first few rows of your dataset to show that you have loaded it successfully.

# %%
# load dataset
df = pd.read_csv('steam_games.csv')
print(df.head())
# Out:
#              game_name  release_year       developer primary_genre  price_usd  \
# 0     Counter-Strike 2          2012           Valve        Action       0.00
# 1               Dota 2          2013           Valve      Strategy       0.00
# 2          ARC Raiders          2025  Embark Studios        Action      39.99
# 3  PUBG: BATTLEGROUNDS          2017     KRAFTON Inc        Action       0.00
# 4            Bongo Cat          2025  Marcel Zurawka        Casual       0.00
#
#    current_players  peak_today  user_rating  num_reviews
# 0          1142703     1325689         86.0      2467622
# 1           615578      740989         88.0       820065
# 2           288711      348253         87.0       149218
# 3           181816      656802         58.0      2500000
# 4           130241      155666         97.0        20123

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# **Steps to Include:**
#
# - Check for and handle any missing values
# - Verify whether data types are appropriate.
# - Generate a statistical summary of each feature.
# - Do you see any outliers? If so, decide how to handle them, and explain your reasoning.

# %%
# add as many code cells here as needed
# Check for missing values
df.isna().sum()
# Out:
# game_name          0
# release_year       0
# developer          0
# primary_genre      0
# price_usd          0
# current_players    0
# peak_today         0
# user_rating        0
# num_reviews        0
# dtype: int64

# %% [markdown]
# No missing values

# %%
# Data types
df.dtypes
# Out:
# game_name           object
# release_year         int64
# developer           object
# primary_genre       object
# price_usd          float64
# current_players      int64
# peak_today           int64
# user_rating        float64
# num_reviews          int64
# dtype: object

# %%
# Statistical summary
df.describe()
# Out:
#        release_year  price_usd  current_players    peak_today  user_rating  \
# count     50.000000   50.00000     5.000000e+01  5.000000e+01    50.000000
# mean    2019.020000   21.83420     9.273010e+04  1.256293e+05    86.800000
# std        4.871785   23.42861     1.763272e+05  2.194302e+05     7.992343
# min     2007.000000    0.00000     3.058700e+04  3.365300e+04    58.000000
# 25%     2015.000000    0.00000     3.438950e+04  4.196900e+04    83.000000
# 50%     2019.000000   17.49000     4.771200e+04  5.993300e+04    88.000000
# 75%     2024.000000   39.99000     6.724100e+04  9.148375e+04    92.000000
# max     2025.000000   69.99000     1.142703e+06  1.325689e+06    97.000000
#
#         num_reviews
# count  5.000000e+01
# mean   3.518688e+05
# std    5.004623e+05
# min    5.000000e+03
# 25%    6.250000e+04
# 50%    2.000000e+05
# 75%    5.000000e+05
# max    2.500000e+06

# %% [markdown]
# No missing values. Data types correct. Summary shows skewed distributions for players/reviews, but expected. No outliers handled as they are valid.

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)
# Visualize the distribution of your features and the relationships between them.
#
# **Steps to Include:**
# - Univariate Analysis: Create a distribution plot (histogram, bar chart, etc.) for each feature. If your dataset includes more than 5 features, you only need to visualize 5.
# - Bivariate Analysis: Create at least two visualizations showing the relationship between pairs of features (e.g. scatterplots, boxplots, etc.).
# - Ensure all plots have appropriate titles and axis labels.

# %%
plt.hist(df['release_year'])
plt.title('Release Year Distribution')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
genre_counts = df['primary_genre'].value_counts()
plt.bar(genre_counts.index, genre_counts.values)
plt.title('Genre Distribution')
plt.xlabel('Genre')
plt.xticks(rotation=45)
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
plt.hist(df['price_usd'])
plt.title('Price Distribution')
plt.xlabel('Price USD')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(12, 6))
developer_counts = df['developer'].value_counts().head(10)  # Top 10 developers
plt.bar(developer_counts.index, developer_counts.values)
plt.title('Top 10 Developer Distribution')
plt.xlabel('Developer')
plt.xticks(rotation=45)
plt.ylabel('Number of Games')
plt.tight_layout()
plt.show()

# %%
plt.hist(df['user_rating'])
plt.title('User Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Observations:**
# * Write a few sentences here interpreting the distribution plots above. What are the trends? Are there imbalances?
#
# 1, Most of top 50 games was published in 2023 - 2025
#
# 2, Action is the most common gerne in the top 50
#
# 3, Free games are the trends in steam platform
#
# 4, Vlave, Embark, Krafton, Marcel, Facepunch are most popular developers within top 50 games
#
# 5, Most of user ratings for top 50 games ranges from 88 to 93

# %%
# Generate relationship plots (remember the labels!)
# Bivariate
plt.scatter(df['current_players'], df['user_rating'])
plt.title('Players vs Rating')
plt.xlabel('Current Players')
plt.ylabel('Rating %')
plt.show()

# %%
df.boxplot(column='price_usd', by='primary_genre', rot=90)
plt.title('Price by Genre')
plt.suptitle('')
plt.xlabel('Genre')
plt.ylabel('Price USD')
plt.grid(False)
plt.show()

# %% [markdown]
# **Observations:**
# * *Write 1-2 sentences interpreting the relationships. Are there correlations? Any interesting patterns?*

# %% [markdown]
# Weak correlation between players and rating; high-player games have varied ratings. RPG/Strategy have higher prices.

# %% [markdown]
# ## Preprocessing Pipeline
# Encapsulate your final preprocessing steps (scaling numeric features, encoding categorical features) into a reusable function or scikit-learn Pipeline. I should be able to create a clean dataset by running a single line of code. This might look like:
# - `clean_data = pipeline.fit_transform(raw_data)`
# - `clean_data = my_cleaning_fn(raw_data)`
#
# **Your preprocessing steps should include:**
# -  Convert categorical variables into dummy variables.
# -  Scale numeric features . *Justify your choice if not using Standard Scaler.*
# -  Handling missing data and outliers, as decided in the previous section.
#
# **After preprocessing, check your work:**
# -  Show the final shape of your clean dataset.
# -  Print the first few rows to make sure all transformations worked.
# -  Generate summary statistics for all features.

# %%
# your code goes here!
def preprocess_data(raw_df):
    df = raw_df.drop(columns=['game_name'])
    
    numeric_features = ['price_usd', 'current_players', 'peak_today', 'user_rating', 'num_reviews']
    categorical_features = ['developer', 'primary_genre','release_year']
    
    num_imputer = SimpleImputer(strategy='mean')
    df[numeric_features] = num_imputer.fit_transform(df[numeric_features])
    
    cat_df = pd.get_dummies(df[categorical_features])
    
    scaler = StandardScaler()
    num_scaled = scaler.fit_transform(df[numeric_features])
    num_df = pd.DataFrame(num_scaled, columns=numeric_features, index=df.index)
    
    clean_df = pd.concat([num_df, cat_df], axis=1)
    
    return clean_df

clean_data = preprocess_data(df)

print("Final shape of clean dataset:", clean_data.shape)
print("First few rows:")
print(clean_data.head().round(2))
print("Summary statistics:")
print(clean_data.describe().round(2))
# Out:
# Final shape of clean dataset: (50, 61)
# First few rows:
#    price_usd  current_players  peak_today  user_rating  num_reviews  \
# 0      -0.94             6.02        5.52        -0.10         4.27
# 1      -0.94             3.00        2.83         0.15         0.95
# 2       0.78             1.12        1.02         0.03        -0.41
# 3      -0.94             0.51        2.45        -3.64         4.34
# 4      -0.94             0.21        0.14         1.29        -0.67
#
#    release_year  developer_Activision  developer_Arrowhead Game Studios  \
# 0          2012                 False                             False
# 1          2013                 False                             False
# 2          2025                 False                             False
# 3          2017                 False                             False
# 4          2025                 False                             False
#
# ...

# %% [markdown]
# ## 5. Reflection
# *Write a few paragraphs reflecting on your experience completing this project.*
#
# * **What was more difficult than expected?**
# * **What part did you enjoy the most?**
# * **How do you think your process would handle a dataset with 1 million+ rows?**

# %% [markdown]
# The preprocessing pipeline was harder than anticipated since I'm new to tools like SimpleImputer and StandardScaler, requiring extra time to integrate them properly without breaking the code.
#
# I enjoyed creating the visualizations most, as plotting distributions and relationships revealed cool trends like free games dominating popularity and correlations between price and ratings.
#
# My manual process wouldn't scale well for 1 million+ rows, as it would take ages to process and demand massive effort for cleaning, so I'd need automation, and optimized pipelines to manage memory.

# %% [markdown]
# ## Final Statements

# %% [markdown]
# 🎉 Congratulations on Completing Project 1! 🥳
#
# You have successfully navigated the most critical phase of the Data Science lifecycle. While building flashy models often gets the spotlight, the work you completed here—curation, cleaning, and exploration—*is the foundation upon which all successful AI/ML systems are built*.
#
# Moreover, **you thought beyond the code!** By tackling the "Datasheets for Datasets" section, you demonstrated ethical awareness and a deep understanding of your data's context, provenance, and potential biases. This distinguishes a **true Data Scientist** from a mere coder.
#
# Again, congratulations! You are now fully equipped to move on to predictive modeling and machine learning! ✨🎊

# %% [markdown]
# # Add any extensions below!
